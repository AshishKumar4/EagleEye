# %%
import paho.mqtt.client as mqtt
import time

# %%
broker = "iot.eclipse.org"
broker_port = 1883

# %%
def on_connect(client, userdata, flags, rc):
    print("Connected with result code "+str(rc))

    # Subscribing in on_connect() means that if we lose the connection and
    # reconnect then subscriptions will be renewed.
    client.subscribe("model1/attendence")

# The callback for when a PUBLISH message is received from the server.
def on_message(client, userdata, msg):
    print(msg.topic+" "+str(msg.payload))

# %%
client = mqtt.Client("Test-123")
client.on_connect = on_connect
client.on_message = on_message

client.connect(broker, broker_port, 60)
# Out:
# 0

# %%
#client.loop_start() #start loop to process received messages
#print("subscribing ")
client.subscribe("model1/attendence")
#time.sleep(2)
#print("publishing ")
#client.publish("home/smart1","on")#publish
#time.sleep(4)
#client.disconnect() #disconnect
#client.loop_stop() #stop loop
client.loop_forever()
# Out:
# Connected with result code 0
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'Davinder'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Ashish'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'CPSingh'
# model1/attendence b'Davinder'
# model1/attendence b'Davinder'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-5bb749b3a8a8> in <module>()
#       8 #client.disconnect() #disconnect
#       9 #client.loop_stop() #stop loop
# ---> 10 client.loop_forever()
#
# /usr/local/lib/python3.7/dist-packages/paho/mqtt/client.py in loop_forever(self, timeout, max_packets, retry_first_connection)
#    1576             rc = MQTT_ERR_SUCCESS
#    1577             while rc == MQTT_ERR_SUCCESS:
# -> 1578                 rc = self.loop(timeout, max_packets)
#    1579                 # We don't need to worry about locking here, because we've
#    1580                 # either called loop_forever() when in single threaded mode, or
#
# /usr/local/lib/python3.7/dist-packages/paho/mqtt/client.py in loop(self, timeout, max_packets)
#    1055         rlist = [self._sock, self._sockpairR]
#    1056         try:
# -> 1057             socklist = select.select(rlist, wlist, [], timeout)
#    1058         except TypeError:
#    1059             # Socket isn't correct type, in likelihood connection is lost
#
# KeyboardInterrupt:

# %%
del client

# %%
client.publish("model1/control/read", b'nfr')
